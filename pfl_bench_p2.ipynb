# %%
## imports
import numpy as np
import cvxpy as cp
import pandas as pd
import matplotlib.pyplot as plt
import itertools
# %run ccpp_light.ipynb
from IPython.display import clear_output
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
clear_output()

# %% [markdown]
# ### data

# %%
dic_results = {'UB':[],'LB':[],'N':[],'repID':[],'time':[],'certif':[],\
               'd':[],'tau':[],'p':[],'skip_':[]}

# %%
''' dimensions & hyper-parameters'''

np.random.seed(2308)

d_list = [int(2)]
skip_list = [False,True]
N = int(5e2)
tau_list =  [.05,.15,.25]
N_reps = int(5)
otilde = 1
o = 2
TL = 500
MT_cert = 60

''' commands '''

xi_inf_bound = 5
x_inf_bound = 10
granularity = 6
frac = 23/50

''' elements  '''
def rnd_pos(p):
    buf = np.zeros(p)
    id_pos = np.random.randint(0,p)
    buf[id_pos]= np.random.choice(np.linspace(-xi_inf_bound,xi_inf_bound,granularity))
    denom = np.random.randint(1,100,p-1)
    buf[np.setdiff1d(np.arange(p),[id_pos])] = xi_inf_bound*np.random.randint(-denom,denom+1,p-1)/denom
    return buf


# from INRIA 
def proj_simplex_(vec, R=1,tol=1e-3):
    """ 
    References
    ----------
    [1] Efficient Projections onto the .1-Ball for Learning in High Dimensions
        John Duchi, Shai Shalev-Shwartz, Yoram Singer, and Tushar Chandra.
        International Conference on Machine Learning (ICML 2008)
        http://www.cs.berkeley.edu/~jduchi/projects/DuchiSiShCh08.pdf
    """
    assert R > 0, "radius R must be strictly positive (%d <= 0)" % R
    d, = vec.shape  # will raise ValueError if vec is not 1-D
    if abs(vec.sum() - R)<=tol and np.alltrue(vec >= 0):
        return vec
    sorted_vec = np.sort(vec)[::-1]
    cssv = np.cumsum(sorted_vec)
    buf = np.nonzero(sorted_vec * np.arange(1, d+1) > (cssv - R))[0][-1]
    shift = float(cssv[buf] - R) / (1+buf)
    w = (vec - shift).clip(min=0)
    return w

## ball proximity based
def proj_ball_(x,xi_embd,nm_power,R,tol=5e-4):
    dxxi_embd = x-xi_embd
    abs_dxxi_embd = np.abs(dxxi_embd)
    if nm_power==1:
        if np.sum(abs_dxxi_embd)<=R+tol:
            return x
        return xi_embd + proj_simplex_(abs_dxxi_embd,R)*np.sign(dxxi_embd)
    elif nm_power==np.inf:
        if max(abs_dxxi_embd)<=R+tol:
            return x
        return xi_embd + np.minimum(R,np.maximum(-R,dxxi_embd))
    elif nm_power==2:
        buf = (np.sum(abs_dxxi_embd**2))**(1/2)
        if buf<=R+tol:
            return x
        return xi_embd + dxxi_embd*R/max(R,buf)
    else:
        return None

# %%
for d in d_list:

    print('====> d = '+str(d))
    print(' ')

    p = d
    
    R_base = 2*d*xi_inf_bound*frac

    x_ref = np.random.choice([-xi_inf_bound,xi_inf_bound],d) + ( (np.arange(d))**2 )/d

    ## numpy set-up ##
    if o==2:
        def obj_val(x):
            return np.sum((x-x_ref)**2)
    else:
        def obj_val(x):
            return np.linalg.norm(x-x_ref,o)
            
    ## cvxpy set-up ##
    x_cvx = cp.Variable(d)
    xi_param = cp.Parameter(p)
    big_bound = max(np.max(np.abs(x_ref)),xi_inf_bound+R_base) # big enough so that min_x in X of F(x) s.t. x in R(s) is the same as min_x of F(x) s.t. x in R(s)
    X = [x_cvx>=-big_bound,x_cvx<=big_bound]
    
    if o==2:
        obj_ = cp.sum_squares(x_cvx-x_ref)
    else:
        obj_ = cp.norm(x_cvx-x_ref,o)

    def cstr_gen_cvxpy(xi_embd,nm_power=otilde,R=R_base):
        return cp.norm(x_cvx-xi_embd,nm_power)-R

    
    if otilde==1:
        
        if p==2:
            c_bound_cvxpy = [x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]]
        elif p==3:
            c_bound_cvxpy = [x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1]+x_cvx[2]-xi_param[2],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1]+x_cvx[2]-xi_param[2],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1]+x_cvx[2]-xi_param[2],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]+x_cvx[2]-xi_param[2],\
                            x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1]-x_cvx[2]+xi_param[2],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1]-x_cvx[2]+xi_param[2],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1]-x_cvx[2]+xi_param[2],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]-x_cvx[2]+xi_param[2]]
    elif otilde==np.inf:
        
        if p==2:
            c_bound_cvxpy = [cp.max([x_cvx[0]-xi_param[0],x_cvx[1]-xi_param[1]]),\
                            cp.max([-x_cvx[0]+xi_param[0],x_cvx[1]-xi_param[1]]),\
                            cp.max([x_cvx[0]-xi_param[0],-x_cvx[1]+xi_param[1]]),\
                            cp.max([-x_cvx[0]+xi_param[0],-x_cvx[1]+xi_param[1]])]
        elif p==3:
            c_bound_cvxpy = [cp.max([x_cvx[0]-xi_param[0],x_cvx[1]-xi_param[1],x_cvx[2]-xi_param[2]]),\
                            cp.max([-x_cvx[0]+xi_param[0],x_cvx[1]-xi_param[1],x_cvx[2]-xi_param[2]]),\
                            cp.max([x_cvx[0]-xi_param[0],-x_cvx[1]+xi_param[1],x_cvx[2]-xi_param[2]]),\
                            cp.max([-x_cvx[0]+xi_param[0],-x_cvx[1]+xi_param[1],x_cvx[2]-xi_param[2]]),\
                            cp.max([x_cvx[0]-xi_param[0],x_cvx[1]-xi_param[1],-x_cvx[2]+xi_param[2]]),\
                            cp.max([-x_cvx[0]+xi_param[0],x_cvx[1]-xi_param[1],-x_cvx[2]+xi_param[2]]),\
                            cp.max([x_cvx[0]-xi_param[0],-x_cvx[1]+xi_param[1],-x_cvx[2]+xi_param[2]]),\
                            cp.max([-x_cvx[0]+xi_param[0],-x_cvx[1]+xi_param[1],-x_cvx[2]+xi_param[2]])]
            
    else:
        
        print('not yet ')

    ################

    def single_s_specialized(xi_s):
        x_s = proj_ball_(x_ref,xi_s,otilde,R_base)
        return obj_val(x_s),[x_s]


    for repID in range(N_reps):

        print(' ')
        print('rep #'+str(repID+1))
        print(' ')

        # xi data generation
        xi_list = np.array([rnd_pos(int(p)) for s in range(N)])
        pis = np.ones(N)/N

        for tau in tau_list:

                print('tau = '+str(tau))
                print(' ')

                for sk in skip_list:

                    print('skip_presolve: '+str(sk))


                    prob = Problem(obj_,X,tau,xi_list,pis,cstr_gen=cstr_gen_cvxpy,\
                                 c_bound=c_bound_cvxpy,rel_tol=1e-2,used_solver=cp.MOSEK,individual_nus_comp=single_s_specialized)
                    

                    stat,timing,_,_,_,_ = prob.solve(include_cuts=False,verbose_general=True,T_max=TL,skip_presolve=sk,\
                                      verbose_certify=True,verbose_prune=True,display=False,max_time_cert=MT_cert,max_rounds=1)

                    dic_results['UB'].append(prob.UB)
                    dic_results['LB'].append(prob.LB)
                    dic_results['N'].append(N)
                    dic_results['repID'].append(repID)
                    dic_results['time'].append(timing)
                    dic_results['certif'].append(stat)
                    dic_results['d'].append(d)
                    dic_results['tau'].append(tau)
                    dic_results['p'].append(p)
                    dic_results['skip_'].append(sk)
                    print(' ')

                    df = pd.DataFrame(data=dic_results)
                    df.to_csv('benchmark_final_p_'+str(p)+'_o_'+str(o)+'_otilde_'+str(otilde)+'.csv')
# Out:
# ====> d = 2
#
#
# rep #1
#
# tau = 0.05
#
# skip_presolve: False
#
# pre-pass oracle...
# LB = 0.0 | self.UB = 53.213986831496875 | pre-pruned: 4
#
#
# empirical cstr (LB): 0.9040000000000004
# current lower-bound: 35.84222241829322
#
#
# empirical cstr (UB): 0.9500000000000004
# current upper-bound: 53.213986831496875
#
#
# trial @6 | remaining checks [%] -> 97.72
# trial @22 | remaining checks [%] -> 88.63
# trial @61 | remaining checks [%] -> 79.54
# trial @126 | remaining checks [%] -> 70.45
# trial @191 | remaining checks [%] -> 61.36
# trial @229 | remaining checks [%] -> 52.27
# trial @283 | remaining checks [%] -> 43.18
# trial @357 | remaining checks [%] -> 34.09
# trial @376 | remaining checks [%] -> 25.0
# trial @409 | remaining checks [%] -> 15.90
# trial @473 | remaining checks [%] -> 6.818
#
# after optimality scan: 0 indices were added to the pruned set
#
#
#  /!\ pre_solve termination /!\
# safe indices: 294 ; pruned indices: 4
# best feasible solution:: 53.213986831496875
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 01:32:55 PM: Your problem has 205 variables, 499 constraints, and 0 parameters.
# (CVXPY) Mar 08 01:32:55 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 01:32:55 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 01:32:55 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:32:55 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 01:32:55 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 01:32:55 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 01:32:55 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 01:32:55 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 01:32:56 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 01:32:56 PM: Finished problem compilation (took 1.497e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:32:56 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 01:32:56 PM: Problem
# (CVXPY) Mar 08 01:32:56 PM:   Name                   :
# (CVXPY) Mar 08 01:32:56 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 01:32:56 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 01:32:56 PM:   Constraints            : 2692
# (CVXPY) Mar 08 01:32:56 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 01:32:56 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 01:32:56 PM:   Cones                  : 1
# (CVXPY) Mar 08 01:32:56 PM:   Scalar variables       : 1202
# (CVXPY) Mar 08 01:32:56 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 01:32:56 PM:   Integer variables      : 202
# (CVXPY) Mar 08 01:32:56 PM:
# (CVXPY) Mar 08 01:32:56 PM: Optimizer started.
# (CVXPY) Mar 08 01:32:56 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 01:32:56 PM: Threads used: 12
# (CVXPY) Mar 08 01:32:56 PM: Presolve started.
# (CVXPY) Mar 08 01:32:56 PM: Presolve terminated. Time = 0.02, probing time =  0.00
# (CVXPY) Mar 08 01:32:56 PM: Presolved problem: 1112 variables, 2482 constraints, 5688 non-zeros
# (CVXPY) Mar 08 01:32:56 PM: Presolved problem: 0 general integer, 115 binary, 997 continuous
# (CVXPY) Mar 08 01:32:56 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 01:32:56 PM: Clique table size: 0
# (CVXPY) Mar 08 01:32:56 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 08 01:32:56 PM: 0        1        1        0        NA                   3.8182936202e+01     NA          0.1
# (CVXPY) Mar 08 01:32:56 PM: 0        1        1        0        8.0034673134e+04     3.8182936202e+01     99.95       0.1
# (CVXPY) Mar 08 01:32:57 PM: Cut generation started.
# (CVXPY) Mar 08 01:32:57 PM: 0        1        1        0        8.0034673134e+04     3.8182936202e+01     99.95       0.4
# (CVXPY) Mar 08 01:32:57 PM: Cut generation terminated. Time = 0.06
# (CVXPY) Mar 08 01:32:57 PM: 8        12       9        2        8.0034673134e+04     3.8471670202e+01     99.95       0.6
# (CVXPY) Mar 08 01:32:57 PM: 20       24       21       3        8.0034673134e+04     3.8803862269e+01     99.95       0.7
# (CVXPY) Mar 08 01:32:57 PM: 45       49       46       6        8.0034673134e+04     3.8993119807e+01     99.95       0.8
# (CVXPY) Mar 08 01:32:57 PM: 81       85       82       9        8.0034673134e+04     3.9287035934e+01     99.95       1.1
# (CVXPY) Mar 08 01:32:58 PM: 153      157      154      15       8.0034673134e+04     3.9287035934e+01     99.95       1.7
# (CVXPY) Mar 08 01:32:59 PM: 297      301      298      27       8.0034673134e+04     3.9287035934e+01     99.95       2.7
# (CVXPY) Mar 08 01:33:00 PM: 585      589      586      51       8.0034673134e+04     3.9287035934e+01     99.95       4.2
# (CVXPY) Mar 08 01:33:02 PM: 881      885      882      76       8.0034673134e+04     3.9287035934e+01     99.95       6.0
# (CVXPY) Mar 08 01:33:04 PM: 1207     1211     1184     102      8.0034673134e+04     3.9287035934e+01     99.95       7.6
: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 08 01:35:33 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 08 01:35:33 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 08 01:35:33 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 08 01:35:33 PM:
# (CVXPY) Mar 08 01:35:33 PM: Objective of best integer solution : 4.944480727980e+01
# (CVXPY) Mar 08 01:35:33 PM: Best objective bound               : 4.944480727980e+01
# (CVXPY) Mar 08 01:35:33 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 01:35:33 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 01:35:33 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 01:35:33 PM: Number of cuts generated           : 0
# (CVXPY) Mar 08 01:35:33 PM: Number of branches                 : 28364
# (CVXPY) Mar 08 01:35:33 PM: Number of relaxations solved       : 24005
# (CVXPY) Mar 08 01:35:33 PM: Number of interior point iterations: 420680
# (CVXPY) Mar 08 01:35:33 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 01:35:33 PM: Time spend presolving the root     : 0.02
# (CVXPY) Mar 08 01:35:33 PM: Time spend optimizing the root     : 0.03
# (CVXPY) Mar 08 01:35:33 PM: Mixed integer optimizer terminated. Time: 156.96
# (CVXPY) Mar 08 01:35:33 PM:
# (CVXPY) Mar 08 01:35:33 PM: Optimizer terminated. Time: 156.99
# (CVXPY) Mar 08 01:35:33 PM:
# (CVXPY) Mar 08 01:35:33 PM:
# (CVXPY) Mar 08 01:35:33 PM: Integer solution solution summary
# (CVXPY) Mar 08 01:35:33 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 01:35:33 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 08 01:35:33 PM:   Primal.  obj: 4.9444807280e+01    nrm: 5e+01    Viol.  con: 8e-10    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:35:33 PM: Problem status: optimal
# (CVXPY) Mar 08 01:35:33 PM: Optimal value: 4.944e+01
# (CVXPY) Mar 08 01:35:33 PM: Compilation took 1.497e+00 seconds
# (CVXPY) Mar 08 01:35:33 PM: Solver (including time spent in interface) took 1.570e+02 seconds
# final target accuracy:: 0.0
# total running time: 235.04889273643494 [s]
# cost:: 49.44488760015554
#
# skip_presolve: True
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 01:36:00 PM: Your problem has 503 variables, 503 constraints, and 0 parameters.
# (CVXPY) Mar 08 01:36:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 01:36:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 01:36:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:36:00 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 01:36:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 01:36:00 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 01:36:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 01:36:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 01:36:01 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 01:36:02 PM: Finished problem compilation (took 1.877e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:36:02 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 01:36:02 PM: Problem
# (CVXPY) Mar 08 01:36:02 PM:   Name                   :
# (CVXPY) Mar 08 01:36:02 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 01:36:02 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 01:36:02 PM:   Constraints            : 3010
# (CVXPY) Mar 08 01:36:02 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 01:36:02 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 01:36:02 PM:   Cones                  : 1
# (CVXPY) Mar 08 01:36:02 PM:   Scalar variables       : 1508
# (CVXPY) Mar 08 01:36:02 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 01:36:02 PM:   Integer variables      : 500
# (CVXPY) Mar 08 01:36:02 PM:
# (CVXPY) Mar 08 01:36:02 PM: Optimizer started.
# (CVXPY) Mar 08 01:36:02 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 01:36:02 PM: Threads used: 12
# (CVXPY) Mar 08 01:36:02 PM: Presolve started.
# (CVXPY) Mar 08 01:36:02 PM: Presolve terminated. Time = 0.02, probing time =  0.00
# (CVXPY) Mar 08 01:36:02 PM: Presolved problem: 1505 variables, 2502 constraints, 6502 non-zeros
# (CVXPY) Mar 08 01:36:02 PM: Presolved problem: 0 general integer, 500 binary, 1005 continuous
# (CVXPY) Mar 08 01:36:02 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 01:36:02 PM: Clique table size: 0
# (CVXPY) Mar 08 01:36:02 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 08 01:36:02 PM: 0        1        1        0        NA                   3.4662340413e+00     NA          0.1
# (CVXPY) Mar 08 01:36:02 PM: 0        1        1        0        8.0053877075e+04     3.4662340413e+00     100.00      0.2
# (CVXPY) Mar 08 01:36:02 PM: Cut generation started.
# (CVXPY) Mar 08 01:36:03 PM: 0        1        1        0        8.0053877075e+04     3.4662340562e+00     100.00      0.7
# (CVXPY) Mar 08 01:36:03 PM: 0        2        1        0        8.0053877075e+04     3.6042455503e+00     100.00      0.9
# (CVXPY) Mar 08 01:36:03 PM: 0        3        1        0        8.0053877075e+04     3.6892854742e+00     100.00      1.0
# (CVXPY) Mar 08 01:36:03 PM: 0        4        1        0        8.0053877075e+04     4.0515580841e+00     99.99       1.1
# (CVXPY) Mar 08 01:36:03 PM: 0        5        1        0        8.0053877075e+04     4.3304400902e+00     99.99       1.3
# (CVXPY) Mar 08 01:36:03 PM: 0        6        1        0        8.0053877075e+04     4.3575949849e+00     99.99       1.4
# (CVXPY) Mar 08 01:36:03 PM: 0        7        1        0        8.0053877075e+04     4.3699573817e+00     99.99       1.5
# (CVXPY) Mar 08 01:36:03 PM: 0        8        1        0        8.0053877075e+04     4.4907799458e+00     99.99       1.7
# (CVXPY) Mar 08 01:36:04 PM: 0        9        1        0        8.0053877075e+04     4.5545244228e+00     99.99       1.8
# (CVXPY) Mar 08 01:36:04 PM: 0        10       1        0        8.0053877075e+04     4.6089155254e+00     99.99       1.9
# (CVXPY) Mar 08 01:36:04 PM: 0        11       1        0        8.0053877075e+04     4.6148455421e+00     99.99       2.1
# (CVXPY) Mar 08 01:36:04 PM: 0        12       1        0        8.0053877075e+04     4.6522152789e+00     99.99       2.2
# (CVXPY) Mar 08 01:36:04 PM: 0        13       1        0        8.0053877075e+04     4.6919665213e+00     99.99       2.3
# (CVXPY) Mar 08 01:36:04 PM: 0        14       1        0        8.0053877075e+04     4.7464559181e+00     99.99       2.5
# (CVXPY) Mar 08 01:36:04 PM: 0        15       1        0        8.0053877075e+04     4.7636594413e+00     99.99       2.6
# (CVXPY) Mar 08 01:41:50 PM: 34880    33880    7627     441      3.9604670633e+03     4.5127644259e+01     98.86       348.5
# (CVXPY) Mar 08 01:41:53 PM: 35196    34194    7647     469      3.9604670633e+03     4.5127644259e+01     98.86       350.8
# (CVXPY) Mar 08 01:41:55 PM: 35510    34507    7663     497      3.9604670633e+03     4.5127644259e+01     98.86       353.5
# (CVXPY) Mar 08 01:41:59 PM: 35876    34817    7645     19       5.0163660627e+02     4.5127644490e+01     91.00       356.8
# (CVXPY) Mar 08 01:42:01 PM: 36768    35121    7077     28       5.0163660627e+02     4.9365658475e+01     90.16       359.4
# (CVXPY) Mar 08 01:42:04 PM: 37338    35433    6797     20       5.0163660627e+02     4.9365660059e+01     90.16       362.1
# (CVXPY) Mar 08 01:42:06 PM: 37973    35749    6482     34       5.0163660627e+02     4.9380133300e+01     90.16       364.7
# (CVXPY) Mar 08 01:42:09 PM: 38810    36057    5995     22       5.0163660627e+02     4.9430195438e+01     90.15       367.3
# (CVXPY) Mar 08 01:42:12 PM: 39133    36380    6250     50       5.0163660627e+02     4.9430195438e+01     90.15       370.2
# (CVXPY) Mar 08 01:42:15 PM: 39457    36704    6462     33       5.0163660627e+02     4.9430198587e+01     90.15       373.1
# (CVXPY) Mar 08 01:42:18 PM: 39764    37011    6383     31       5.0163660627e+02     4.9432838568e+01     90.15       376.1
# (CVXPY) Mar 08 01:42:20 PM: 40068    37315    6259     50       5.0163660627e+02     4.9432849850e+01     90.15       378.6
# (CVXPY) Mar 08 01:42:23 PM: 40372    37619    6079     24       5.0163660627e+02     4.9442240347e+01     90.14       381.2
# (CVXPY) Mar 08 01:42:26 PM: 40930    37927    5781     25       5.0163660627e+02     4.9442242727e+01     90.14       383.9
# (CVXPY) Mar 08 01:42:28 PM: 41553    38239    5446     30       5.0163660627e+02     4.9444516509e+01     90.14       386.5
# (CVXPY) Mar 08 01:42:31 PM: 42260    38551    5073     21       5.0163660627e+02     4.9444885325e+01     90.14       389.3
# (CVXPY) Mar 08 01:42:34 PM: 43271    38852    4370     67       4.9456669571e+01     4.9444886812e+01     0.02        392.1
# (CVXPY) Mar 08 01:42:34 PM: 47631    38877    12       375      4.9444879046e+01     4.9444879046e+01     0.00e+00    392.5
# (CVXPY) Mar 08 01:42:34 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 08 01:42:34 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 08 01:42:34 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 08 01:42:34 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 08 01:42:34 PM:
# (CVXPY) Mar 08 01:42:34 PM: Objective of best integer solution : 4.944487904624e+01
# (CVXPY) Mar 08 01:42:34 PM: Best objective bound               : 4.944487904624e+01
# (CVXPY) Mar 08 01:42:34 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 01:42:34 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 01:42:34 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 01:42:34 PM: Number of cuts generated           : 211
# (CVXPY) Mar 08 01:42:34 PM:   Number of CMIR cuts              : 211
# (CVXPY) Mar 08 01:42:34 PM: Number of branches                 : 47631
# (CVXPY) Mar 08 01:42:34 PM: Number of relaxations solved       : 38877
# (CVXPY) Mar 08 01:42:34 PM: Number of interior point iterations: 751908
# (CVXPY) Mar 08 01:42:34 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 01:42:34 PM: Time spend presolving the root     : 0.02
# (CVXPY) Mar 08 01:42:34 PM: Time spend optimizing the root     : 0.04
# (CVXPY) Mar 08 01:42:34 PM: Mixed integer optimizer terminated. Time: 392.47
# (CVXPY) Mar 08 01:42:34 PM:
# (CVXPY) Mar 08 01:42:34 PM: Optimizer terminated. Time: 392.52
# (CVXPY) Mar 08 01:42:34 PM:
# (CVXPY) Mar 08 01:42:34 PM:
# (CVXPY) Mar 08 01:42:34 PM: Integer solution solution summary
# (CVXPY) Mar 08 01:42:34 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 01:42:34 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 08 01:42:34 PM:   Primal.  obj: 4.9444879046e+01    nrm: 5e+01    Viol.  con: 7e-09    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:42:34 PM: Problem status: optimal
# (CVXPY) Mar 08 01:42:34 PM: Optimal value: 4.944e+01
# (CVXPY) Mar 08 01:42:34 PM: Compilation took 1.877e+00 seconds
# (CVXPY) Mar 08 01:42:34 PM: Solver (including time spent in interface) took 3.925e+02 seconds
# final target accuracy:: 0.0
# total running time: 420.81182312965393 [s]
# cost:: 49.44488677926765
#
# tau = 0.15
#
# skip_presolve: False
#
# pre-pass oracle...
# LB = 0.0 | self.UB = 24.90468778696051 | pre-pruned: 62
#
#
# empirical cstr (LB): 0.8120000000000003
# current lower-bound: 17.570041119394304
#
#
# empirical cstr (UB): 0.8500000000000003
# current upper-bound: 24.90468778696051
#
#
# trial @11 | remaining checks [%] -> 96.87
# trial @77 | remaining checks [%] -> 87.5
# trial @98 | remaining checks [%] -> 78.12
# trial @250 | remaining checks [%] -> 68.75
# trial @306 | remaining checks [%] -> 59.37
# trial @357 | remaining checks [%] -> 50.0
# trial @368 | remaining checks [%] -> 40.62
# trial @385 | remaining checks [%] -> 31.25
# trial @400 | remaining checks [%] -> 21.87
# trial @437 | remaining checks [%] -> 12.5
# trial @479 | remaining checks [%] -> 3.125
#
# after optimality scan: 0 indices were added to the pruned set
#
#
#  /!\ pre_solve termination /!\
# safe indices: 278 ; pruned indices: 62
# best feasible solution:: 24.90468778696051
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 01:43:43 PM: Your problem has 163 variables, 441 constraints, and 0 parameters.
# (CVXPY) Mar 08 01:43:43 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 01:43:43 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 01:43:43 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:43:43 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 01:43:43 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 01:43:43 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 01:43:43 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 01:43:43 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 01:43:44 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 01:43:44 PM: Finished problem compilation (took 1.369e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 01:43:44 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 01:43:44 PM: Problem
# (CVXPY) Mar 08 01:43:44 PM:   Name                   :
# (CVXPY) Mar 08 01:43:44 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 01:43:44 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 01:43:44 PM:   Constraints            : 2360
# (CVXPY) Mar 08 01:43:44 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 01:43:44 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 01:43:44 PM:   Cones                  : 1
# (CVXPY) Mar 08 01:43:44 PM:   Scalar variables       : 1044
# (CVXPY) Mar 08 01:43:44 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 01:43:44 PM:   Integer variables      : 160
# (CVXPY) Mar 08 01:43:44 PM:
# (CVXPY) Mar 08 01:43:44 PM: Optimizer started.
# (CVXPY) Mar 08 01:43:44 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 01:43:44 PM: Threads used: 12
# (CVXPY) Mar 08 01:43:44 PM: Presolve started.
# (CVXPY) Mar 08 01:43:44 PM: Presolve terminated. Time = 0.02, probing time =  0.00
# (CVXPY) Mar 08 01:43:44 PM: Presolved problem: 964 variables, 2192 constraints, 4986 non-zeros
# (CVXPY) Mar 08 01:43:44 PM: Presolved problem: 0 general integer, 83 binary, 881 continuous
# (CVXPY) Mar 08 01:43:44 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 01:43:44 PM: Clique table size: 0
# (CVXPY) Mar 08 01:43:44 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 08 01:43:44 PM: 0        1        1        0        NA                   2.0017063959e+01     NA          0.1
# (CVXPY) Mar 08 01:43:45 PM: 0        1        1        0        8.0017628203e+04     2.0017063959e+01     99.97       0.2
# (CVXPY) Mar 08 01:43:45 PM: Cut generation started.
# (CVXPY) Mar 08 01:43:45 PM: 0        1        1        0        8.0017628203e+04     2.0017063959e+01     99.97       0.4
# (CVXPY) Mar 08 01:43:45 PM: Cut generation terminated. Time = 0.05
# (CVXPY) Mar 08 01:43:45 PM: 8        12       9        2        8.0017628203e+04     2.0377636868e+01     99.97       0.6
# (CVXPY) Mar 08 01:43:45 PM: 20       24       21       4        8.0017628203e+04     2.1030354979e+01     99.97       0.7
# (CVXPY) Mar 08 01:43:45 PM: 43       47       44       5        8.0017628203e+04     2.1460815827e+01     99.97       0.9
# (CVXPY) Mar 08 01:43:46 PM: 79       83       80       8        8.0017628203e+04     2.1843196973e+01     99.97       1.1
# ...
# (CVXPY) Mar 08 04:08:08 PM: 15713    15679    15522    95       3.3859044560e+04     -9.8643589847e-07    100.00      146.5
# (CVXPY) Mar 08 04:08:11 PM: 16001    15967    15810    80       3.3859044560e+04     -9.8643589847e-07    100.00      149.5
# (CVXPY) Mar 08 04:08:14 PM: 16289    16255    16098    68       3.3859044560e+04     -9.8643589847e-07    100.00      152.5
# (CVXPY) Mar 08 04:08:17 PM: 16589    16555    16398    142      3.3859044560e+04     -9.8643589847e-07    100.00      155.5
# (CVXPY) Mar 08 04:08:20 PM: 16865    16831    16674    77       3.3859044560e+04     -9.8643589847e-07    100.00      158.5
# (CVXPY) Mar 08 04:08:23 PM: 17147    17113    16956    186      3.3859044560e+04     -9.8643589847e-07    100.00      161.6
# (CVXPY) Mar 08 04:08:26 PM: 17428    17394    17237    154      3.3859044560e+04     -9.8643589847e-07    100.00      164.7
# (CVXPY) Mar 08 04:08:29 PM: 17707    17673    17516    158      3.3859044560e+04     -9.8643589847e-07    100.00      167.9
# (CVXPY) Mar 08 04:08:33 PM: 17986    17952    17795    116      3.3859044560e+04     -9.8643589847e-07    100.00      171.2
# (CVXPY) Mar 08 04:08:36 PM: 18265    18231    18074    118      3.3859044560e+04     -9.8643589847e-07    100.00      174.4
# (CVXPY) Mar 08 04:08:39 PM: 18522    18488    18331    118      3.3859044560e+04     -9.8643589847e-07    100.00      177.8
# (CVXPY) Mar 08 04:08:43 PM: 18801    18767    18610    129      3.3859044560e+04     -9.8643589847e-07    100.00      181.1
# (CVXPY) Mar 08 04:08:46 PM: 19079    19045    18888    134      3.3859044560e+04     -9.8643589847e-07    100.00      184.4
# (CVXPY) Mar 08 04:08:49 PM: 19356    19322    19165    139      3.3859044560e+04     -9.8643589847e-07    100.00      187.6
# (CVXPY) Mar 08 04:08:52 PM: 19632    19598    19441    96       3.3859044560e+04     -9.8643589847e-07    100.00      190.9
# (CVXPY) Mar 08 04:08:56 PM: 19911    19877    19718    159      3.3859044560e+04     -9.8643589847e-07    100.00      194.5
# (CVXPY) Mar 08 04:08:59 PM: 20185    20151    19992    186      3.3859044560e+04     -9.8643589847e-07    100.00      197.7
# (CVXPY) Mar 08 04:09:03 PM: 20465    20431    20272    213      3.3859044560e+04     -9.8643589847e-07    100.00      201.2
# (CVXPY) Mar 08 04:09:06 PM: 20749    20715    20556    240      3.3859044560e+04     -9.8643589847e-07    100.00      204.6
# (CVXPY) Mar 08 04:09:09 PM: 21045    21011    20786    267      3.3859044560e+04     -9.8643589847e-07    100.00      208.0
# (CVXPY) Mar 08 04:09:13 PM: 21354    21320    21083    296      3.3859044560e+04     -9.8643589847e-07    100.00      211.3
# (CVXPY) Mar 08 04:09:16 PM: 21657    21623    21386    325      3.3859044560e+04     -9.8643589847e-07    100.00      214.8
# (CVXPY) Mar 08 04:09:19 PM: 21959    21925    21688    353      3.3859044560e+04     -9.8643589847e-07    100.00      218.0
# (CVXPY) Mar 08 04:09:23 PM: 22258    22224    21987    382      3.3859044560e+04     -9.8643589847e-07    100.00      221.1
# (CVXPY) Mar 08 04:09:26 PM: 22557    22523    22286    410      3.3859044560e+04     -9.8643589847e-07    100.00      224.2
# (CVXPY) Mar 08 04:09:29 PM: 22862    22828    22591    438      3.3859044560e+04     -9.8643589847e-07    100.00      227.3
# (CVXPY) Mar 08 04:09:32 PM: 23163    23129    22892    466      3.3859044560e+04     -9.8643589847e-07    100.00      230.4
# (CVXPY) Mar 08 04:09:35 PM: 23461    23426    23186    150      1.3980853564e+04     -9.8643589847e-07    100.00      233.6
# (CVXPY) Mar 08 04:09:38 PM: 23747    23712    23348    94       1.3980853564e+04     -9.8643589847e-07    100.00      236.8
# (CVXPY) Mar 08 04:09:41 PM: 24041    24006    23414    118      1.3980853564e+04     -9.8643589847e-07    100.00      239.9
# (CVXPY) Mar 08 04:09:45 PM: 24325    24290    23490    36       1.3980853000e+04     -9.8643589847e-07    100.00      243.1
# (CVXPY) Mar 08 04:09:48 PM: 24638    24603    23721    156      1.3980853000e+04     -9.8643589847e-07    100.00      246.2
# (CVXPY) Mar 08 04:09:51 PM: 24965    24930    24010    187      1.3980853000e+04     -9.8643589847e-07    100.00      249.1
# (CVXPY) Mar 08 04:09:54 PM: 25294    25259    24303    194      1.3980853000e+04     -9.8643589847e-07    100.00      252.1
# (CVXPY) Mar 08 04:09:57 PM: 25620    25585    24585    166      1.3980853000e+04     -9.8643589847e-07    100.00      255.2
# (CVXPY) Mar 08 04:10:00 PM: 25943    25908    24862    149      1.3980853000e+04     -9.8643589847e-07    100.00      258.3
# (CVXPY) Mar 08 04:10:03 PM: 26265    26230    25158    170      1.3980853000e+04     -9.8643589847e-07    100.00      261.3
# (CVXPY) Mar 08 04:10:06 PM: 26582    26547    25427    164      1.3980853000e+04     -9.8643589847e-07    100.00      264.2
# (CVXPY) Mar 08 04:10:09 PM: 26901    26866    25698    166      1.3980853000e+04     -9.8643589847e-07    100.00      267.2
# (CVXPY) Mar 08 04:10:11 PM: 27220    27185    25975    155      1.3980853000e+04     -9.8643589847e-07    100.00      269.9
# (CVXPY) Mar 08 04:10:14 PM: 27513    27478    26238    156      1.3980853000e+04     -9.8643589847e-07    100.00      272.7
# (CVXPY) Mar 08 04:10:17 PM: 27831    27796    26512    165      1.3980853000e+04     -9.8643589847e-07    100.00      275.4
# (CVXPY) Mar 08 04:10:20 PM: 28149    28112    26782    177      1.1850656664e+04     -9.8643589847e-07    100.00      278.2
# (CVXPY) Mar 08 04:10:23 PM: 28460    28410    26871    181      1.1850656664e+04     -9.8643589847e-07    100.00      281.2
# (CVXPY) Mar 08 04:10:26 PM: 28759    28709    26972    208      1.1850656664e+04     -9.8643589847e-07    100.00      284.2
# (CVXPY) Mar 08 04:10:29 PM: 29057    29007    27084    232      1.1850656664e+04     -9.8643589847e-07    100.00      287.3
# (CVXPY) Mar 08 04:10:32 PM: 29360    29310    27235    258      1.1850656664e+04     -9.8643589847e-07    100.00      290.3
# (CVXPY) Mar 08 04:10:35 PM: 29676    29626    27545    285      1.1850656664e+04     -9.8643589847e-07    100.00      293.4
# (CVXPY) Mar 08 04:10:38 PM: 29986    29935    27849    312      1.2591206239e+03     -9.8643589847e-07    100.00      296.5
# (CVXPY) Mar 08 04:10:41 PM: 30300    30247    28153    51       1.2591206239e+03     -9.8643589847e-07    100.00      299.7
# (CVXPY) Mar 08 04:10:44 PM: 30605    30552    28456    63       1.2591206239e+03     -9.8643589847e-07    100.00      302.9
# (CVXPY) Mar 08 04:10:47 PM: 30912    30859    28759    72       1.2591206239e+03     -9.8643589847e-07    100.00      306.0
# (CVXPY) Mar 08 04:10:51 PM: 31221    31168    29066    84       1.2591206239e+03     -9.8643589847e-07    100.00      309.2
# (CVXPY) Mar 08 04:10:54 PM: 31536    31483    29379    93       1.2591206239e+03     -9.8643589847e-07    100.00      312.5
# (CVXPY) Mar 08 04:10:57 PM: 31847    31794    29684    95       1.2591206239e+03     -9.8643589847e-07    100.00      315.9
# (CVXPY) Mar 08 04:11:01 PM: 32159    32106    29994    73       1.2591206239e+03     -9.8643589847e-07    100.00      319.3
# (CVXPY) Mar 08 04:11:04 PM: 32468    32415    30301    45       1.2591206239e+03     -9.8643589847e-07    100.00      322.8
# (CVXPY) Mar 08 04:11:08 PM: 32779    32726    30608    88       1.2591206239e+03     -9.8643589847e-07    100.00      326.2
# (CVXPY) Mar 08 04:11:11 PM: 33054    32999    30875    96       1.2591192016e+03     -9.8643589847e-07    100.00      329.8
# (CVXPY) Mar 08 04:11:15 PM: 33366    33311    31185    72       1.2591192016e+03     -9.8643589847e-07    100.00      333.3
# (CVXPY) Mar 08 04:11:18 PM: 33678    33623    31493    86       1.2591192016e+03     -9.8643589847e-07    100.00      336.7
# (CVXPY) Mar 08 04:11:21 PM: 33993    33938    31806    108      1.2591192016e+03     -9.8643589847e-07    100.00      340.0
# (CVXPY) Mar 08 04:11:24 PM: 34308    34253    32115    140      1.2591192016e+03     -9.8643589847e-07    100.00      343.0
# (CVXPY) Mar 08 04:11:28 PM: 34616    34561    32423    172      1.2591192016e+03     -9.8643589847e-07    100.00      346.2
# (CVXPY) Mar 08 04:11:31 PM: 34948    34893    32749    203      1.2591192016e+03     -9.8643589847e-07    100.00      349.1
# (CVXPY) Mar 08 04:11:33 PM: 35287    35232    33082    231      1.2591192016e+03     -9.8643589847e-07    100.00      351.8
# (CVXPY) Mar 08 04:11:36 PM: 35631    35576    33426    259      1.2591192016e+03     -9.8643589847e-07    100.00      354.5
# (CVXPY) Mar 08 04:11:39 PM: 35979    35924    33774    287      1.2591192016e+03     -9.8643589847e-07    100.00      357.1
# (CVXPY) Mar 08 04:11:41 PM: 36321    36266    34116    314      1.2591192016e+03     -9.8643589847e-07    100.00      359.8
# (CVXPY) Mar 08 04:11:44 PM: 36654    36599    34449    342      1.2591192016e+03     -9.8643589847e-07    100.00      362.3
# (CVXPY) Mar 08 04:11:46 PM: 36986    36931    34781    369      1.2591192016e+03     -9.8643589847e-07    100.00      364.9
# (CVXPY) Mar 08 04:11:49 PM: 37315    37260    35110    396      1.2591192016e+03     -9.8643589847e-07    100.00      367.4
# (CVXPY) Mar 08 04:11:51 PM: 37642    37587    35437    423      1.2591192016e+03     -9.8643589847e-07    100.00      370.0
# (CVXPY) Mar 08 04:11:54 PM: 37967    37912    35760    451      1.2591192016e+03     -9.8643589847e-07    100.00      372.4
# (CVXPY) Mar 08 04:11:56 PM: 38293    38238    36086    479      1.2591192016e+03     -9.8643589847e-07    100.00      374.7
# (CVXPY) Mar 08 04:11:59 PM: 38617    38561    36406    94       4.7054463549e+01     -9.8643589847e-07    100.00      377.1
# (CVXPY) Mar 08 04:12:01 PM: 38939    38875    36712    106      4.7054463549e+01     -9.8643589847e-07    100.00      379.5
# (CVXPY) Mar 08 04:12:03 PM: 39231    39163    36984    98       3.7580418247e+01     -9.8643589847e-07    100.00      382.0
# (CVXPY) Mar 08 04:12:06 PM: 39548    39473    37237    70       3.7570544837e+01     -9.8643589847e-07    100.00      384.7
# (CVXPY) Mar 08 04:12:09 PM: 39852    39777    37419    72       3.7570544837e+01     -9.8643589847e-07    100.00      387.3
# (CVXPY) Mar 08 04:12:11 PM: 40158    40083    37601    74       3.7570544837e+01     -9.8643589847e-07    100.00      390.1
# (CVXPY) Mar 08 04:12:14 PM: 40462    40387    37811    76       3.7570544837e+01     -9.8643589847e-07    100.00      392.8
# (CVXPY) Mar 08 04:12:17 PM: 40769    40694    37984    101      3.7570544837e+01     -9.8643589847e-07    100.00      395.6
# (CVXPY) Mar 08 04:12:20 PM: 41076    41001    38153    76       3.7570544837e+01     -9.8643589847e-07    100.00      398.4
# (CVXPY) Mar 08 04:12:23 PM: 41387    41312    38316    80       3.7570544837e+01     -9.8643589847e-07    100.00      401.4
# (CVXPY) Mar 08 04:12:26 PM: 41693    41618    38508    90       3.7570544837e+01     -9.8643589847e-07    100.00      404.4
# (CVXPY) Mar 08 04:12:29 PM: 41999    41924    38646    70       3.7570544837e+01     -9.8643589847e-07    100.00      407.2
# (CVXPY) Mar 08 04:12:32 PM: 42306    42231    38771    77       3.7570544837e+01     -9.8643589847e-07    100.00      410.2
# (CVXPY) Mar 08 04:12:35 PM: 42611    42536    38936    80       3.7570544837e+01     -9.8643589847e-07    100.00      413.2
# (CVXPY) Mar 08 04:12:38 PM: 42921    42846    39122    103      3.7570544837e+01     -9.8643589847e-07    100.00      416.1
# (CVXPY) Mar 08 04:12:40 PM: 43234    43159    39305    133      3.7570544837e+01     -9.8643589847e-07    100.00      418.9
# (CVXPY) Mar 08 04:12:43 PM: 43545    43470    39508    163      3.7570544837e+01     -9.8643589847e-07    100.00      421.9
# (CVXPY) Mar 08 04:12:46 PM: 43856    43781    39701    193      3.7570544837e+01     -9.8643589847e-07    100.00      424.8
# (CVXPY) Mar 08 04:12:49 PM: 44159    44084    39896    222      3.7570544837e+01     -9.8643589847e-07    100.00      427.6
# (CVXPY) Mar 08 04:12:52 PM: 44477    44401    40074    251      3.5333893104e+01     -9.8643589847e-07    100.00      430.4
# (CVXPY) Mar 08 04:12:55 PM: 44790    44706    40155    115      3.5333893104e+01     -9.8643589847e-07    100.00      433.4
# (CVXPY) Mar 08 04:12:58 PM: 45101    45017    40282    100      3.5333893104e+01     -9.8643589847e-07    100.00      436.3
# (CVXPY) Mar 08 04:13:01 PM: 45394    45310    40423    109      3.5333893104e+01     -9.8643589847e-07    100.00      439.3
# (CVXPY) Mar 08 04:13:04 PM: 45715    45631    40562    100      3.5333893104e+01     -9.8643589847e-07    100.00      442.2
# (CVXPY) Mar 08 04:13:07 PM: 46034    45950    40763    113      3.5333893104e+01     -9.8643589847e-07    100.00      445.1
# (CVXPY) Mar 08 04:13:09 PM: 46352    46268    40931    193      3.5333893104e+01     -9.8643589847e-07    100.00      447.9
# (CVXPY) Mar 08 04:13:12 PM: 46668    46584    41147    68       3.5333893104e+01     -9.8643589847e-07    100.00      450.8
# (CVXPY) Mar 08 04:13:15 PM: 46984    46900    41351    92       3.5333893104e+01     -9.8643589847e-07    100.00      454.0
# (CVXPY) Mar 08 04:13:18 PM: 47303    47219    41516    102      3.5333893104e+01     -9.8643589847e-07    100.00      456.7
# (CVXPY) Mar 08 04:13:21 PM: 47619    47535    41706    112      3.5333893104e+01     -9.8643589847e-07    100.00      459.5
# (CVXPY) Mar 08 04:13:24 PM: 47931    47847    41900    96       3.5333893104e+01     -9.8643589847e-07    100.00      462.4
# (CVXPY) Mar 08 04:13:27 PM: 48245    48161    42100    106      3.5333893104e+01     -9.8643589847e-07    100.00      465.2
# (CVXPY) Mar 08 04:13:29 PM: 48561    48477    42278    166      3.5333893104e+01     -9.8643589847e-07    100.00      467.8
# (CVXPY) Mar 08 04:13:32 PM: 48876    48790    42397    133      3.4521201208e+01     -9.8643589847e-07    100.00      470.5
# (CVXPY) Mar 08 04:13:35 PM: 49189    49097    42450    143      3.4521201208e+01     -9.8643589847e-07    100.00      473.7
# (CVXPY) Mar 08 04:13:38 PM: 49494    49402    42581    137      3.4521201208e+01     -9.8643589847e-07    100.00      476.7
# (CVXPY) Mar 08 04:13:39 PM:
# (CVXPY) Mar 08 04:13:39 PM: Objective of best integer solution : 3.452120120786e+01
# (CVXPY) Mar 08 04:13:39 PM: Best objective bound               : -9.864358984664e-07
# (CVXPY) Mar 08 04:13:39 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 04:13:39 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 04:13:39 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 04:13:39 PM: Number of cuts generated           : 0
# (CVXPY) Mar 08 04:13:39 PM: Number of branches                 : 49494
# (CVXPY) Mar 08 04:13:39 PM: Number of relaxations solved       : 49402
# (CVXPY) Mar 08 04:13:39 PM: Number of interior point iterations: 931365
# (CVXPY) Mar 08 04:13:39 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 04:13:39 PM: Time spend presolving the root     : 0.02
# (CVXPY) Mar 08 04:13:39 PM: Time spend optimizing the root     : 0.04
# (CVXPY) Mar 08 04:13:39 PM: Mixed integer optimizer terminated. Time: 477.83
# (CVXPY) Mar 08 04:13:39 PM:
# (CVXPY) Mar 08 04:13:39 PM: Optimizer terminated. Time: 477.95
# (CVXPY) Mar 08 04:13:39 PM:
# (CVXPY) Mar 08 04:13:39 PM:
# (CVXPY) Mar 08 04:13:39 PM: Integer solution solution summary
# (CVXPY) Mar 08 04:13:39 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 04:13:39 PM:   Solution status : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 04:13:39 PM:   Primal.  obj: 3.4521201208e+01    nrm: 4e+01    Viol.  con: 4e-09    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:13:39 PM: Problem status: optimal_inaccurate
# (CVXPY) Mar 08 04:13:39 PM: Optimal value: 3.452e+01
# (CVXPY) Mar 08 04:13:39 PM: Compilation took 1.619e+00 seconds
# (CVXPY) Mar 08 04:13:39 PM: Solver (including time spent in interface) took 4.780e+02 seconds
# final target accuracy:: inf
# total running time: 501.8864779472351 [s]
# cost:: 34.52140565069803
