# %%
## imports
import numpy as np
import cvxpy as cp
import pandas as pd
import matplotlib.pyplot as plt
import itertools
# %run ccpp_light.ipynb
from IPython.display import clear_output
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
clear_output()

# %% [markdown]
# ### data

# %%
dic_results = {'UB':[],'LB':[],'N':[],'repID':[],'time':[],'certif':[],\
               'd':[],'tau':[],'p':[],'skip_':[]}

# %%
''' dimensions & hyper-parameters'''

np.random.seed(2308)

d_list = [int(3)]
skip_list = [False,True]
N = int(5e2)
tau_list =  [.05,.15,.25]
N_reps = int(5)
otilde = 1
o = 2
TL = 720
MT_cert = 120

''' commands '''

xi_inf_bound = 5
x_inf_bound = 10
granularity = 6
frac = 23/50

''' elements  '''
def rnd_pos(p):
    buf = np.zeros(p)
    id_pos = np.random.randint(0,p)
    buf[id_pos]= np.random.choice(np.linspace(-xi_inf_bound,xi_inf_bound,granularity))
    denom = np.random.randint(1,100,p-1)
    buf[np.setdiff1d(np.arange(p),[id_pos])] = xi_inf_bound*np.random.randint(-denom,denom+1,p-1)/denom
    return buf


# from INRIA 
def proj_simplex_(vec, R=1,tol=1e-3):
    """ 
    References
    ----------
    [1] Efficient Projections onto the .1-Ball for Learning in High Dimensions
        John Duchi, Shai Shalev-Shwartz, Yoram Singer, and Tushar Chandra.
        International Conference on Machine Learning (ICML 2008)
        http://www.cs.berkeley.edu/~jduchi/projects/DuchiSiShCh08.pdf
    """
    assert R > 0, "radius R must be strictly positive (%d <= 0)" % R
    d, = vec.shape  # will raise ValueError if vec is not 1-D
    if abs(vec.sum() - R)<=tol and np.alltrue(vec >= 0):
        return vec
    sorted_vec = np.sort(vec)[::-1]
    cssv = np.cumsum(sorted_vec)
    buf = np.nonzero(sorted_vec * np.arange(1, d+1) > (cssv - R))[0][-1]
    shift = float(cssv[buf] - R) / (1+buf)
    w = (vec - shift).clip(min=0)
    return w

## ball proximity based
def proj_ball_(x,xi_embd,nm_power,R,tol=5e-4):
    dxxi_embd = x-xi_embd
    abs_dxxi_embd = np.abs(dxxi_embd)
    if nm_power==1:
        if np.sum(abs_dxxi_embd)<=R+tol:
            return x
        return xi_embd + proj_simplex_(abs_dxxi_embd,R)*np.sign(dxxi_embd)
    elif nm_power==np.inf:
        if max(abs_dxxi_embd)<=R+tol:
            return x
        return xi_embd + np.minimum(R,np.maximum(-R,dxxi_embd))
    elif nm_power==2:
        buf = (np.sum(abs_dxxi_embd**2))**(1/2)
        if buf<=R+tol:
            return x
        return xi_embd + dxxi_embd*R/max(R,buf)
    else:
        return None

# %%
for d in d_list:

    print('====> d = '+str(d))
    print(' ')

    p = d
    
    R_base = 2*d*xi_inf_bound*frac

    x_ref = np.random.choice([-xi_inf_bound,xi_inf_bound],d) + ( (np.arange(d))**2 )/d

    ## numpy set-up ##
    if o==2:
        def obj_val(x):
            return np.sum((x-x_ref)**2)
    else:
        def obj_val(x):
            return np.linalg.norm(x-x_ref,o)
            
    ## cvxpy set-up ##
    x_cvx = cp.Variable(d)
    xi_param = cp.Parameter(p)
    big_bound = max(np.max(np.abs(x_ref)),xi_inf_bound+R_base) # big enough so that min_x in X of F(x) s.t. x in R(s) is the same as min_x of F(x) s.t. x in R(s)
    X = [x_cvx>=-big_bound,x_cvx<=big_bound]
    
    if o==2:
        obj_ = cp.sum_squares(x_cvx-x_ref)
    else:
        obj_ = cp.norm(x_cvx-x_ref,o)

    def cstr_gen_cvxpy(xi_embd,nm_power=otilde,R=R_base):
        return cp.norm(x_cvx-xi_embd,nm_power)-R

    
    if otilde==1:
        
        if p==2:
            c_bound_cvxpy = [x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]]
        elif p==3:
            c_bound_cvxpy = [x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1]+x_cvx[2]-xi_param[2],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1]+x_cvx[2]-xi_param[2],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1]+x_cvx[2]-xi_param[2],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]+x_cvx[2]-xi_param[2],\
                            x_cvx[0]-xi_param[0]+x_cvx[1]-xi_param[1]-x_cvx[2]+xi_param[2],\
                            -x_cvx[0]+xi_param[0]+x_cvx[1]-xi_param[1]-x_cvx[2]+xi_param[2],\
                            x_cvx[0]-xi_param[0]-x_cvx[1]+xi_param[1]-x_cvx[2]+xi_param[2],\
                            -x_cvx[0]+xi_param[0]-x_cvx[1]+xi_param[1]-x_cvx[2]+xi_param[2]]
    elif otilde==np.inf:
        
        c_bound_cvxpy = []
        for j in range(p):
            for signum in [-1,1]:
                c_bound_cvxpy += [signum*(x_cvx[j]-xi_param[j])]
            
    else:
        
        print('not yet ')

    ################

    def single_s_specialized(xi_s):
        x_s = proj_ball_(x_ref,xi_s,otilde,R_base)
        return obj_val(x_s),[x_s]


    for repID in range(N_reps):

        print(' ')
        print('rep #'+str(repID+1))
        print(' ')

        # xi data generation
        xi_list = np.array([rnd_pos(int(p)) for s in range(N)])
        pis = np.ones(N)/N

        for tau in tau_list:

                print('tau = '+str(tau))
                print(' ')

                for sk in skip_list:

                    print('skip_presolve: '+str(sk))


                    prob = Problem(obj_,X,tau,xi_list,pis,cstr_gen=cstr_gen_cvxpy,\
                                 c_bound=c_bound_cvxpy,rel_tol=1e-2,used_solver=cp.MOSEK,individual_nus_comp=single_s_specialized)
                    

                    stat,timing,_,_,_,_ = prob.solve(include_cuts=False,verbose_general=True,T_max=TL,skip_presolve=sk,\
                                      verbose_certify=True,verbose_prune=True,display=False,max_time_cert=MT_cert,max_rounds=1)
                    dic_results['UB'].append(prob.UB)
                    dic_results['LB'].append(prob.LB)
                    dic_results['N'].append(N)
                    dic_results['repID'].append(repID)
                    dic_results['time'].append(timing)
                    dic_results['certif'].append(stat)
                    dic_results['d'].append(d)
                    dic_results['tau'].append(tau)
                    dic_results['p'].append(p)
                    dic_results['skip_'].append(sk)
                    print(' ')

                    df = pd.DataFrame(data=dic_results)
                    df.to_csv('benchmark_final_p_'+str(p)+'_o_'+str(o)+'_otilde_'+str(otilde)+'.csv')
# Out:
# ====> d = 3
#
#
# rep #1
#
# tau = 0.05
#
# skip_presolve: False
#
# pre-pass oracle...
# LB = 0.0 | self.UB = 39.30062733590166 | pre-pruned: 11
#
#
# empirical cstr (LB): 0.7180000000000002
# current lower-bound: 5.576333165743179
#
#
# empirical cstr (UB): 0.9540000000000004
# current upper-bound: 37.06533832827507
#
#
# trial @1 | remaining checks [%] -> 99.23
# trial @41 | remaining checks [%] -> 89.23
# trial @97 | remaining checks [%] -> 79.23
# trial @152 | remaining checks [%] -> 69.23
# trial @208 | remaining checks [%] -> 59.23
# pruned! @224
# trial @284 | remaining checks [%] -> 49.23
# trial @325 | remaining checks [%] -> 39.23
# pruned! @325
# trial @362 | remaining checks [%] -> 29.23
# trial @407 | remaining checks [%] -> 19.23
# trial @460 | remaining checks [%] -> 9.230
#
# after optimality scan: 2 indices were added to the pruned set
#
#
#  /!\ pre_solve termination /!\
# safe indices: 22 ; pruned indices: 13
# best feasible solution:: 37.06533832827507
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 04:47:39 PM: Your problem has 469 variables, 490 constraints, and 0 parameters.
# (CVXPY) Mar 08 04:47:39 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 04:47:39 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 04:47:39 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:47:39 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 04:47:39 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 04:47:39 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 04:47:39 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 04:47:39 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 04:47:40 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 04:47:40 PM: Finished problem compilation (took 1.691e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:47:40 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 04:47:40 PM: Problem
# (CVXPY) Mar 08 04:47:40 PM:   Name                   :
# (CVXPY) Mar 08 04:47:40 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 04:47:40 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 04:47:40 PM:   Constraints            : 3887
# (CVXPY) Mar 08 04:47:40 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 04:47:40 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 04:47:40 PM:   Cones                  : 1
# (CVXPY) Mar 08 04:47:40 PM:   Scalar variables       : 1936
# (CVXPY) Mar 08 04:47:40 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 04:47:40 PM:   Integer variables      : 465
# (CVXPY) Mar 08 04:47:40 PM:
# (CVXPY) Mar 08 04:47:40 PM: Optimizer started.
# (CVXPY) Mar 08 04:47:40 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 04:47:40 PM: Threads used: 12
# (CVXPY) Mar 08 04:47:40 PM: Presolve started.
# (CVXPY) Mar 08 04:47:40 PM: Presolve terminated. Time = 0.03, probing time =  0.00
# (CVXPY) Mar 08 04:47:40 PM: Presolved problem: 1874 variables, 3411 constraints, 8608 non-zeros
# (CVXPY) Mar 08 04:47:40 PM: Presolved problem: 0 general integer, 407 binary, 1467 continuous
# (CVXPY) Mar 08 04:47:40 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 04:47:40 PM: Clique table size: 0
# (CVXPY) Mar 08 04:47:40 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar
# (CVXPY) Mar 08 04:50:02 PM: 12165    12145    4652     146      4.0584368195e+01     3.4948050484e+01     13.89       141.6
# (CVXPY) Mar 08 04:50:05 PM: 12448    12428    4723     170      4.0584368195e+01     3.4948050484e+01     13.89       144.8
# (CVXPY) Mar 08 04:50:08 PM: 12754    12734    4787     196      4.0584368195e+01     3.4948050484e+01     13.89       148.1
# (CVXPY) Mar 08 04:50:12 PM: 13059    13039    4850     222      3.8479552893e+01     3.4948050484e+01     9.18        151.2
# (CVXPY) Mar 08 04:50:14 PM: 13373    13351    4578     183      3.8479552893e+01     3.5291982979e+01     8.28        154.0
# (CVXPY) Mar 08 04:50:17 PM: 13690    13653    4391     15       3.8479552893e+01     3.5295623025e+01     8.27        157.0
# (CVXPY) Mar 08 04:50:21 PM: 14358    13941    4075     31       3.8479552893e+01     3.5503719544e+01     7.73        160.4
# (CVXPY) Mar 08 04:50:24 PM: 14895    14242    3828     41       3.8099251987e+01     3.5533935970e+01     6.73        163.8
# (CVXPY) Mar 08 04:50:28 PM: 15363    14545    3692     62       3.5931857099e+01     3.5533935970e+01     1.11        167.1
# (CVXPY) Mar 08 04:50:31 PM: 16033    14839    3266     69       3.5931857099e+01     3.5639088306e+01     0.81        170.5
# (CVXPY) Mar 08 04:50:34 PM: 16605    15131    3002     15       3.5931857099e+01     3.5727836263e+01     0.57        173.9
# (CVXPY) Mar 08 04:50:37 PM: 17656    15409    2265     102      3.5931857099e+01     3.5727880502e+01     0.57        177.1
# (CVXPY) Mar 08 04:50:40 PM: 18628    15678    1571     184      3.5931857099e+01     3.5727880502e+01     0.57        179.9
# (CVXPY) Mar 08 04:50:43 PM: 19466    15942    999      24       3.5931857099e+01     3.5727895204e+01     0.57        182.6
# (CVXPY) Mar 08 04:50:45 PM: 20169    16184    540      109      3.5931857099e+01     3.5727895343e+01     0.57        185.0
# (CVXPY) Mar 08 04:50:48 PM: 20604    16417    337      128      3.5931857099e+01     3.5727895343e+01     0.57        187.3
# (CVXPY) Mar 08 04:50:50 PM: 20923    16649    268      151      3.5931857099e+01     3.5727895343e+01     0.57        189.7
# (CVXPY) Mar 08 04:50:52 PM: 21183    16871    188      173      3.5931857099e+01     3.5727895343e+01     0.57        192.0
# (CVXPY) Mar 08 04:50:54 PM: 21359    17034    18       198      3.5931857099e+01     3.5814079024e+01     0.33        193.6
# (CVXPY) Mar 08 04:50:54 PM: An optimal solution satisfying the relative gap tolerance of 1.00e-02(%) has been located.
# (CVXPY) Mar 08 04:50:54 PM: The relative gap is 0.00e+00(%).
# (CVXPY) Mar 08 04:50:54 PM: An optimal solution satisfying the absolute gap tolerance of 0.00e+00 has been located.
# (CVXPY) Mar 08 04:50:54 PM: The absolute gap is 0.00e+00.
# (CVXPY) Mar 08 04:50:54 PM:
# (CVXPY) Mar 08 04:50:54 PM: Objective of best integer solution : 3.593185709905e+01
# (CVXPY) Mar 08 04:50:54 PM: Best objective bound               : 3.593185709905e+01
# (CVXPY) Mar 08 04:50:54 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 04:50:54 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 04:50:54 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 04:50:54 PM: Number of cuts generated           : 0
# (CVXPY) Mar 08 04:50:54 PM: Number of branches                 : 21376
# (CVXPY) Mar 08 04:50:54 PM: Number of relaxations solved       : 17042
# (CVXPY) Mar 08 04:50:54 PM: Number of interior point iterations: 337092
# (CVXPY) Mar 08 04:50:54 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 04:50:54 PM: Time spend presolving the root     : 0.03
# (CVXPY) Mar 08 04:50:54 PM: Time spend optimizing the root     : 0.09
# (CVXPY) Mar 08 04:50:54 PM: Mixed integer optimizer terminated. Time: 193.76
# (CVXPY) Mar 08 04:50:54 PM:
# (CVXPY) Mar 08 04:50:54 PM: Optimizer terminated. Time: 193.78
# (CVXPY) Mar 08 04:50:54 PM:
# (CVXPY) Mar 08 04:50:54 PM:
# (CVXPY) Mar 08 04:50:54 PM: Integer solution solution summary
# (CVXPY) Mar 08 04:50:54 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 04:50:54 PM:   Solution status : INTEGER_OPTIMAL
# (CVXPY) Mar 08 04:50:54 PM:   Primal.  obj: 3.5931857099e+01    nrm: 4e+01    Viol.  con: 2e-09    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:50:54 PM: Problem status: optimal
# (CVXPY) Mar 08 04:50:54 PM: Optimal value: 3.593e+01
# (CVXPY) Mar 08 04:50:54 PM: Compilation took 1.691e+00 seconds
# (CVXPY) Mar 08 04:50:54 PM: Solver (including time spent in interface) took 1.938e+02 seconds
# final target accuracy:: 0.0
# total running time: 390.8813638687134 [s]
# cost:: 35.9320313317912
#
# skip_presolve: True
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 04:51:31 PM: Your problem has 504 variables, 503 constraints, and 0 parameters.
# (CVXPY) Mar 08 04:51:31 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 04:51:31 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 04:51:31 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:51:31 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 04:51:31 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 04:51:31 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 04:51:32 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 04:51:32 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 04:51:33 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 04:51:34 PM: Finished problem compilation (took 2.604e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 04:51:34 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 04:51:34 PM: Problem
# (CVXPY) Mar 08 04:51:34 PM:   Name                   :
# (CVXPY) Mar 08 04:51:34 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 04:51:34 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 04:51:34 PM:   Constraints            : 4013
# (CVXPY) Mar 08 04:51:34 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 04:51:34 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 04:51:34 PM:   Cones                  : 1
# (CVXPY) Mar 08 04:51:34 PM:   Scalar variables       : 2010
# (CVXPY) Mar 08 04:51:34 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 04:51:34 PM:   Integer variables      : 500
# (CVXPY) Mar 08 04:51:34 PM:
# (CVXPY) Mar 08 04:51:34 PM: Optimizer started.
# (CVXPY) Mar 08 04:51:34 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 04:51:34 PM: Threads used: 12
# (CVXPY) Mar 08 04:51:34 PM: Presolve started.
# (CVXPY) Mar 08 04:51:34 PM: Presolve terminated. Time = 0.04, probing time =  0.00
# (CVXPY) Mar 08 04:51:34 PM: Presolved problem: 2006 variables, 3502 constraints, 9002 non-zeros
# (CVXPY) Mar 08 04:51:34 PM: Presolved problem: 0 general integer, 500 binary, 1506 continuous
# (CVXPY) Mar 08 04:51:34 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 04:51:34 PM: Clique table size: 0
# (CVXPY) Mar 08 04:51:34 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar
# (CVXPY) Mar 08 05:02:34 PM: 61299    57250    5532     38       3.6819384703e+01     3.0305653847e+01     17.69       660.4
# (CVXPY) Mar 08 05:02:38 PM: 61612    57563    5569     34       3.6819384703e+01     3.0305684785e+01     17.69       664.1
# (CVXPY) Mar 08 05:02:41 PM: 61927    57878    5612     37       3.6819384703e+01     3.0305684785e+01     17.69       667.8
# (CVXPY) Mar 08 05:02:45 PM: 62243    58194    5652     31       3.6819384703e+01     3.0305684785e+01     17.69       671.5
# (CVXPY) Mar 08 05:02:49 PM: 62558    58508    5665     33       3.6819384703e+01     3.0305744756e+01     17.69       675.1
# (CVXPY) Mar 08 05:02:52 PM: 62872    58822    5685     35       3.6819384703e+01     3.0305750117e+01     17.69       678.8
# (CVXPY) Mar 08 05:02:56 PM: 63187    59135    5706     34       3.6819384703e+01     3.0305763779e+01     17.69       682.7
# (CVXPY) Mar 08 05:02:57 PM:
# (CVXPY) Mar 08 05:02:57 PM: Objective of best integer solution : 3.681938470290e+01
# (CVXPY) Mar 08 05:02:57 PM: Best objective bound               : 3.030576377904e+01
# (CVXPY) Mar 08 05:02:57 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 05:02:57 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 05:02:57 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 05:02:57 PM: Number of cuts generated           : 77
# (CVXPY) Mar 08 05:02:57 PM:   Number of CMIR cuts              : 77
# (CVXPY) Mar 08 05:02:57 PM: Number of branches                 : 63187
# (CVXPY) Mar 08 05:02:57 PM: Number of relaxations solved       : 59135
# (CVXPY) Mar 08 05:02:57 PM: Number of interior point iterations: 1083083
# (CVXPY) Mar 08 05:02:57 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 05:02:57 PM: Time spend presolving the root     : 0.04
# (CVXPY) Mar 08 05:02:57 PM: Time spend optimizing the root     : 0.08
# (CVXPY) Mar 08 05:02:57 PM: Mixed integer optimizer terminated. Time: 683.39
# (CVXPY) Mar 08 05:02:57 PM:
# (CVXPY) Mar 08 05:02:57 PM: Optimizer terminated. Time: 683.42
# (CVXPY) Mar 08 05:02:57 PM:
# (CVXPY) Mar 08 05:02:57 PM:
# (CVXPY) Mar 08 05:02:57 PM: Integer solution solution summary
# (CVXPY) Mar 08 05:02:57 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 05:02:57 PM:   Solution status : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 05:02:57 PM:   Primal.  obj: 3.6819384703e+01    nrm: 7e+01    Viol.  con: 2e-08    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 05:02:57 PM: Problem status: optimal_inaccurate
# (CVXPY) Mar 08 05:02:57 PM: Optimal value: 3.682e+01
# (CVXPY) Mar 08 05:02:57 PM: Compilation took 2.604e+00 seconds
# (CVXPY) Mar 08 05:02:57 PM: Solver (including time spent in interface) took 6.834e+02 seconds
# final target accuracy:: inf
# total running time: 722.8180289268494 [s]
# cost:: 36.8196060504546
#
# tau = 0.15
#
# skip_presolve: False
#
# pre-pass oracle...
# /opt/anaconda3/lib/python3.7/site-packages/cvxpy/problems/problem.py:1386: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "
# LB = 0.0 | self.UB = 16.726463406931064 | pre-pruned: 55
#
#
# empirical cstr (LB): 0.7180000000000002
# current lower-bound: 5.576332999470015
#
#
# empirical cstr (UB): 0.8500000000000003
# current upper-bound: 16.32439773416428
#
#
# trial @1 | remaining checks [%] -> 98.83
# trial @29 | remaining checks [%] -> 89.53
# pruned! @41
# trial @79 | remaining checks [%] -> 80.23
# trial @151 | remaining checks [%] -> 70.93
# pruned! @160
# trial @208 | remaining checks [%] -> 61.62
# pruned! @218
# trial @278 | remaining checks [%] -> 52.32
# pruned! @319
# trial @323 | remaining checks [%] -> 43.02
# trial @357 | remaining checks [%] -> 33.72
# trial @397 | remaining checks [%] -> 24.41
# trial @443 | remaining checks [%] -> 15.11
# pruned! @462
# trial @469 | remaining checks [%] -> 5.813
#
# after optimality scan: 5 indices were added to the pruned set
#
#
#  /!\ pre_solve termination /!\
# safe indices: 29 ; pruned indices: 60
# best feasible solution:: 16.32439773416428
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 05:06:05 PM: Your problem has 415 variables, 443 constraints, and 0 parameters.
# (CVXPY) Mar 08 05:06:05 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 05:06:05 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 05:06:05 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# ...
# (CVXPY) Mar 08 09:20:05 PM: 37743    37692    35158    326      3.4550991690e+01     -5.8397346664e-06    100.00      536.1
# (CVXPY) Mar 08 09:20:09 PM: 38043    37992    35458    352      3.4550991690e+01     -5.8397346664e-06    100.00      540.1
# (CVXPY) Mar 08 09:20:13 PM: 38344    38293    35757    378      3.4550991690e+01     -5.8397346664e-06    100.00      543.8
# (CVXPY) Mar 08 09:20:17 PM: 38643    38592    36056    403      3.4550991690e+01     -5.8397346664e-06    100.00      547.7
# (CVXPY) Mar 08 09:20:21 PM: 38946    38892    36347    428      3.4243280935e+01     -5.8397346664e-06    100.00      551.5
# (CVXPY) Mar 08 09:20:25 PM: 39254    39188    36631    79       3.4243280935e+01     -5.8397346664e-06    100.00      556.0
# (CVXPY) Mar 08 09:20:30 PM: 39524    39458    36901    80       3.4243280935e+01     -5.8397346664e-06    100.00      560.5
# (CVXPY) Mar 08 09:20:34 PM: 39820    39754    37197    130      3.4243280935e+01     -5.8397346664e-06    100.00      564.8
# (CVXPY) Mar 08 09:20:39 PM: 40114    40048    37491    106      3.4243280935e+01     -5.8397346664e-06    100.00      569.3
# (CVXPY) Mar 08 09:20:43 PM: 40410    40344    37785    104      3.4243280935e+01     -5.8397346664e-06    100.00      573.7
# (CVXPY) Mar 08 09:20:47 PM: 40704    40638    38063    102      3.4243280935e+01     -5.8397346664e-06    100.00      578.0
# (CVXPY) Mar 08 09:20:52 PM: 40999    40933    38354    97       3.4243280935e+01     -5.8397346664e-06    100.00      582.4
# (CVXPY) Mar 08 09:20:56 PM: 41292    41226    38643    91       3.4243280935e+01     -5.8397346664e-06    100.00      586.9
# (CVXPY) Mar 08 09:21:01 PM: 41586    41520    38929    77       3.4243280935e+01     -5.8397346664e-06    100.00      591.3
# (CVXPY) Mar 08 09:21:05 PM: 41879    41813    39208    65       3.4243280935e+01     -5.8397346664e-06    100.00      595.6
# (CVXPY) Mar 08 09:21:09 PM: 42172    42106    39493    68       3.4243280935e+01     -5.8397346664e-06    100.00      599.9
# (CVXPY) Mar 08 09:21:14 PM: 42468    42402    39763    94       3.4243280935e+01     -5.8397346664e-06    100.00      604.3
# (CVXPY) Mar 08 09:21:18 PM: 42761    42695    40036    100      3.4243280935e+01     -5.8397346664e-06    100.00      608.5
# (CVXPY) Mar 08 09:21:22 PM: 43053    42987    40310    100      3.4243280935e+01     -5.8397346664e-06    100.00      612.9
# (CVXPY) Mar 08 09:21:27 PM: 43347    43281    40596    75       3.4243280935e+01     -5.8397346664e-06    100.00      617.2
# (CVXPY) Mar 08 09:21:31 PM: 43638    43572    40879    79       3.4243280935e+01     -5.8397346664e-06    100.00      621.6
# (CVXPY) Mar 08 09:21:35 PM: 43932    43866    41161    82       3.4243280935e+01     -5.8397346664e-06    100.00      626.0
# (CVXPY) Mar 08 09:21:40 PM: 44229    44163    41404    76       3.4243280935e+01     -5.8397346664e-06    100.00      630.5
# (CVXPY) Mar 08 09:21:44 PM: 44528    44462    41603    90       3.4243280935e+01     -5.8397346664e-06    100.00      634.8
# (CVXPY) Mar 08 09:21:48 PM: 44826    44760    41879    115      3.4243280935e+01     -5.8397346664e-06    100.00      639.1
# (CVXPY) Mar 08 09:21:53 PM: 45136    45070    42125    95       3.4243280935e+01     -5.8207430900e-06    100.00      643.4
# (CVXPY) Mar 08 09:21:57 PM: 45419    45351    42368    82       3.4235219243e+01     -5.7508729178e-06    100.00      648.0
# (CVXPY) Mar 08 09:22:02 PM: 45723    45649    42614    86       3.4235219243e+01     -5.7354585597e-06    100.00      652.5
# (CVXPY) Mar 08 09:22:06 PM: 46024    45950    42893    72       3.4235219243e+01     -5.7061547615e-06    100.00      657.0
# (CVXPY) Mar 08 09:22:11 PM: 46326    46252    43181    85       3.4235219243e+01     -5.5658571596e-06    100.00      661.4
# (CVXPY) Mar 08 09:22:15 PM: 46624    46550    43475    112      3.4235219243e+01     -5.4562694439e-06    100.00      665.8
# (CVXPY) Mar 08 09:22:19 PM: 46925    46851    43770    114      3.4235219243e+01     -5.4065147785e-06    100.00      670.0
# (CVXPY) Mar 08 09:22:23 PM: 47227    47153    44072    34       3.4235219243e+01     -5.3577187105e-06    100.00      674.2
# (CVXPY) Mar 08 09:22:28 PM: 47529    47455    44374    65       3.4235219243e+01     -5.3577187105e-06    100.00      678.4
# (CVXPY) Mar 08 09:22:28 PM: Maximum amount of time 678.42 (=dpar_optimizer_max_time) is reached.
# (CVXPY) Mar 08 09:22:28 PM:
# (CVXPY) Mar 08 09:22:28 PM: Objective of best integer solution : 3.423521924301e+01
# (CVXPY) Mar 08 09:22:28 PM: Best objective bound               : -5.357718710476e-06
# (CVXPY) Mar 08 09:22:28 PM: Initial feasible solution objective: Undefined
# (CVXPY) Mar 08 09:22:28 PM: Construct solution objective       : Not employed
# (CVXPY) Mar 08 09:22:28 PM: User objective cut value           : Not employed
# (CVXPY) Mar 08 09:22:28 PM: Number of cuts generated           : 0
# (CVXPY) Mar 08 09:22:28 PM: Number of branches                 : 47529
# (CVXPY) Mar 08 09:22:28 PM: Number of relaxations solved       : 47455
# (CVXPY) Mar 08 09:22:28 PM: Number of interior point iterations: 938784
# (CVXPY) Mar 08 09:22:28 PM: Number of simplex iterations       : 0
# (CVXPY) Mar 08 09:22:28 PM: Time spend presolving the root     : 0.02
# (CVXPY) Mar 08 09:22:28 PM: Time spend optimizing the root     : 0.06
# (CVXPY) Mar 08 09:22:28 PM: Mixed integer optimizer terminated. Time: 678.43
# (CVXPY) Mar 08 09:22:28 PM:
# (CVXPY) Mar 08 09:22:28 PM: Optimizer terminated. Time: 678.52
# (CVXPY) Mar 08 09:22:28 PM:
# (CVXPY) Mar 08 09:22:28 PM:
# (CVXPY) Mar 08 09:22:28 PM: Integer solution solution summary
# (CVXPY) Mar 08 09:22:28 PM:   Problem status  : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 09:22:28 PM:   Solution status : PRIMAL_FEASIBLE
# (CVXPY) Mar 08 09:22:28 PM:   Primal.  obj: 3.4235219243e+01    nrm: 7e+01    Viol.  con: 8e-09    var: 0e+00    cones: 0e+00    itg: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 09:22:28 PM: Problem status: optimal_inaccurate
# (CVXPY) Mar 08 09:22:28 PM: Optimal value: 3.424e+01
# (CVXPY) Mar 08 09:22:28 PM: Compilation took 1.633e+00 seconds
# (CVXPY) Mar 08 09:22:28 PM: Solver (including time spent in interface) took 6.785e+02 seconds
# final target accuracy:: inf
# total running time: 721.8514568805695 [s]
# cost:: 34.23600313504944
#
# tau = 0.25
#
# skip_presolve: False
#
# pre-pass oracle...
# LB = 0.0 | self.UB = 4.852386587771204 | pre-pruned: 103
#
# colinearity detected...
# colinearity detected...
#
# empirical cstr (LB): 0.6660000000000001
# current lower-bound: 1.6637207807357703
#
#
# empirical cstr (UB): 0.7500000000000002
# current upper-bound: 4.852386587771204
#
#
# trial @1 | remaining checks [%] -> 98.43
# trial @41 | remaining checks [%] -> 89.06
# trial @97 | remaining checks [%] -> 79.68
# pruned! @113
# pruned! @121
# trial @127 | remaining checks [%] -> 70.31
# trial @146 | remaining checks [%] -> 60.93
# trial @214 | remaining checks [%] -> 51.56
# trial @317 | remaining checks [%] -> 42.18
# trial @365 | remaining checks [%] -> 32.81
# trial @404 | remaining checks [%] -> 23.43
# trial @445 | remaining checks [%] -> 14.06
# trial @477 | remaining checks [%] -> 4.687
#
# after optimality scan: 2 indices were added to the pruned set
#
#
#  /!\ pre_solve termination /!\
# safe indices: 37 ; pruned indices: 105
# best feasible solution:: 4.852386587771204
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Mar 08 09:25:31 PM: Your problem has 362 variables, 398 constraints, and 0 parameters.
# (CVXPY) Mar 08 09:25:31 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Mar 08 09:25:31 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Mar 08 09:25:31 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 09:25:31 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Mar 08 09:25:31 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Mar 08 09:25:31 PM: Applying reduction Dcp2Cone
# (CVXPY) Mar 08 09:25:31 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Mar 08 09:25:31 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Mar 08 09:25:32 PM: Applying reduction MOSEK
# (CVXPY) Mar 08 09:25:32 PM: Finished problem compilation (took 1.198e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Mar 08 09:25:32 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Mar 08 09:25:32 PM: Problem
# (CVXPY) Mar 08 09:25:32 PM:   Name                   :
# (CVXPY) Mar 08 09:25:32 PM:   Objective sense        : minimize
# (CVXPY) Mar 08 09:25:32 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Mar 08 09:25:32 PM:   Constraints            : 3136
# (CVXPY) Mar 08 09:25:32 PM:   Affine conic cons.     : 0
# (CVXPY) Mar 08 09:25:32 PM:   Disjunctive cons.      : 0
# (CVXPY) Mar 08 09:25:32 PM:   Cones                  : 1
# (CVXPY) Mar 08 09:25:32 PM:   Scalar variables       : 1553
# (CVXPY) Mar 08 09:25:32 PM:   Matrix variables       : 0
# (CVXPY) Mar 08 09:25:32 PM:   Integer variables      : 358
# (CVXPY) Mar 08 09:25:32 PM:
# (CVXPY) Mar 08 09:25:32 PM: Optimizer started.
# (CVXPY) Mar 08 09:25:32 PM: Mixed integer optimizer started.
# (CVXPY) Mar 08 09:25:32 PM: Threads used: 12
# (CVXPY) Mar 08 09:25:32 PM: Presolve started.
# (CVXPY) Mar 08 09:25:32 PM: Presolve terminated. Time = 0.02, probing time =  0.00
# (CVXPY) Mar 08 09:25:32 PM: Presolved problem: 1487 variables, 2767 constraints, 6914 non-zeros
# (CVXPY) Mar 08 09:25:32 PM: Presolved problem: 0 general integer, 296 binary, 1191 continuous
# (CVXPY) Mar 08 09:25:32 PM: Presolved problem: 1 cones
# (CVXPY) Mar 08 09:25:32 PM: Clique table size: 0
# (CVXPY) Mar 08 09:25:32 PM: BRANCHES RELAXS   ACT_NDS  DEPTH    BEST_INT_OBJ         BEST_RELAX_OBJ       REL_GAP(%)  TIME
# (CVXPY) Mar 08 09:25:32 PM: 0        1        1        0        NA                   2.1463950325e+00     NA          0.1
# (CVXPY) Mar 08 09:25:32 PM: 0        1        1        0        2.3023140570e+04     2.1463950325e+00     99.99       0.2
# (CVXPY) Mar 08 09:25:33 PM: Cut generation started.
# (CVXPY) Mar 08 09:25:33 PM: 0        1        1        0        2.3023140570e+04     2.1463950183e+00     99.99       0.7
# (CVXPY) Mar 08 09:25:33 PM: Cut generation terminated. Time = 0.06
# (CVXPY) Mar 08 09:25:33 PM: 10       14       11       3        2.3023140570e+04     2.1734012742e+00     99.99       1.0
# (CVXPY) Mar 08 09:25:33 PM: 26       30       27       4        2.3023140570e+04     2.1734012742e+00     99.99       1.2
# (CVXPY) Mar 08 09:25:33 PM: 44       48       45       6        2.3023140570e+04     2.1734012742e+00     99.99       1.4
# (CVXPY) Mar 08 09:25:34 PM: 80       84       81       9        2.3023140570e+04     2.1734012742e+00     99.99       1.7
# (CVXPY) Mar 08 09:25:34 PM: 152      156      151      14       2.3023140570e+04     2.1734012742e+00     99.99       2.4
# (CVXPY) Mar 08 09:25:36 PM: 296      300      295      26       2.3023140570e+04     2.1734012742e+00     99.99       3.5
# (CVXPY) Mar 08 09:25:38 PM: 583      587      582      50       2.3023140570e+04     2.1734012742e+00     99.99       6.0
# (CVXPY) Mar 08 09:25:41 PM: 866      870      865      76       2.3023140570e+04     2.1734012742e+00     99.99       8.6
# (CVXPY) Mar 08 09:25:43 PM: 1174     1178     1173     104      2.3023140570e+04     2.1734012742e+00     99.99       11.2
# (CVXPY) Mar 08 09:25:46 PM: 1489     1493     1488     133      2.3023140570e+04     2.1734012742e+00     99.99       13.7
# (CVXPY) Mar 08 09:25:48 PM: 1801     1805     1800     161      2.3023140570e+04     2.1734012742e+00     99.99       16.2
# (CVXPY) Mar 08 09:25:51 PM: 2097     2101     2086     189      2.3023140570e+04     2.1734012742e+00     99.99       18.9
# (CVXPY) Mar 08 09:25:53 PM: 2395     2399     2384     217      2.3023140570e+04     2.1734012742e+00     99.99       21.5
